# %%
import pandas as pd

# %%
df = pd.read_csv ('data/player_info.csv')
df
# Out:
#     pid    team name  number  pos   b_t   wt  ht        born       debut  \
# 0   742  中信兄弟二軍  王則鈞      33   投手  右投右打  181  86  1995/08/07  2014/03/27
# 1  4626  中信兄弟二軍  王奕凱      54   投手  左投左打  183  80  2000/08/29  2019/05/15
# 2   929    中信兄弟  王威晨       9  二壘手  右投左打  183  75  1991/07/03  2016/04/26
# 3  2307  中信兄弟二軍  王政順      61  三壘手  右投左打  175  78  1996/10/30         NaN
# 4  1387  中信兄弟二軍  王梓安      37   投手  右投右打  198  90  1990/10/09  2014/03/23
#
#     edu nationality original_name          draft
# 0  遠東科大        中華民國           NaN    兄弟象2013年第三輪
# 1  城市科大        中華民國           NaN   中信兄弟2018年第五輪
# 2  輔仁大學        中華民國           NaN  中信兄弟2015年第十三輪
# 3  桃園農工        中華民國           王崇穎   中信兄弟2018年第六輪
# 4  吳鳳科大        中華民國           NaN    兄弟象2013年第四輪
